# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\akina\Downloads\playlist_2010to2022.csv")

# %%
df.shape
# Out:
# (2300, 23)

# %%
df["playlist_url"].head()
# Out:
# 0    https://open.spotify.com/playlist/37i9dQZF1DWU...
# 1    https://open.spotify.com/playlist/37i9dQZF1DWU...
# 2    https://open.spotify.com/playlist/37i9dQZF1DWU...
# 3    https://open.spotify.com/playlist/37i9dQZF1DWU...
# 4    https://open.spotify.com/playlist/37i9dQZF1DWU...
# Name: playlist_url, dtype: object

# %%
df2= df.groupby("track_name")["track_popularity"]

# %%
plt.plot(df["artist_popularity"]),
legend();
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4984/538828443.py in <module>
#       1 plt.plot(df["artist_popularity"]),
# ----> 2 legend();
#
# NameError: name 'legend' is not defined

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2300 entries, 0 to 2299
# Data columns (total 23 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   playlist_url       2300 non-null   object
#  1   year               2300 non-null   int64
#  2   track_id           2300 non-null   object
#  3   track_name         2300 non-null   object
#  4   track_popularity   2300 non-null   int64
#  5   album              2300 non-null   object
#  6   artist_id          2300 non-null   object
#  7   artist_name        2300 non-null   object
#  8   artist_genres      2300 non-null   object
#  9   artist_popularity  2300 non-null   int64
#  10  danceability       2299 non-null   float64
#  11  energy             2299 non-null   float64
#  12  key                2299 non-null   float64
#  13  loudness           2299 non-null   float64
#  14  mode               2299 non-null   float64
#  15  speechiness        2299 non-null   float64
# ...

# %%
df["artist_popularity"].corr("track_popularity")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4984/1306931976.py in <module>
# ----> 1 df["artist_popularity"].corr("track_popularity")
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in corr(self, other, method, min_periods)
#    2501         0.3
#    2502         """
# -> 2503         this, other = self.align(other, join="inner", copy=False)
#    2504         if len(this) == 0:
#    2505             return np.nan
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in align(self, other, join, axis, level, copy, fill_value, method, limit, fill_axis, broadcast_axis)
#    4433         broadcast_axis=None,
#    4434     ):
# -> 4435         return super().align(
#    4436             other,
#    4437             join=join,
#
# ...

# %%
df.plot()
# Out:
# <AxesSubplot:>
